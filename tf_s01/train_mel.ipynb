# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
from tqdm import tqdm

# managing files
from glob import glob
from shutil import copyfile

# tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D, Conv2D, MaxPool2D, ZeroPadding2D, BatchNormalization, Input, DepthwiseConv2D, Add, LeakyReLU, ReLU
from tensorflow.keras.optimizers import Adam, SGD

# Audio
import librosa
import librosa.display as dsp
import IPython.display as ipd

# Augmentation
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift

# %%
train_csv = pd.read_csv('data/train_data.csv')
train_csv
# Out:
#         id  age  gender  respiratory_condition  fever_or_muscle_pain  covid19
# 0        1   24  female                      0                     1        0
# 1        2   51    male                      0                     0        0
# 2        3   22    male                      0                     0        0
# 3        4   29  female                      1                     0        0
# 4        5   23    male                      0                     0        0
# ...    ...  ...     ...                    ...                   ...      ...
# 3800  3801   53    male                      0                     0        0
# 3801  3802   25    male                      0                     0        0
# 3802  3803   26  female                      0                     0        0
# 3803  3804   27  female                      0                     0        0
# 3804  3805   49  female                      1                     1        0
#
# [3805 rows x 6 columns]

# %%
# Define Augmentation
augment = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.5),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
    Shift(min_fraction=-0.5, max_fraction=0.5, p=0.5),
])

# %%
train_path = glob('data\\train\\*.*')
len(train_path)
# Out:
# 3805

# %%
# Audio augmentation
def path_to_mel(path, augmentation):
    audio, sr = librosa.load(path, sr=16000)

    if augmentation == True:
        audio = augment(samples=audio, sample_rate=16000)
        audio = np.hstack([audio, np.zeros(340000 - audio.shape[0])])

    elif augmentation == False:
        audio = np.hstack([audio, np.zeros(340000 - audio.shape[0])])
        
    mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)

    return np.array(mel, np.float64)

# %%
train_csv.loc[int(train_path[1].split('\\')[-1].split('.')[0])][5]
# Out:
# 0

# %%
data = []
label = []

for i in tqdm(train_path):

    if train_csv.loc[int(i.split('\\')[-1].split('.')[0])][5] == 1:
        data.append(path_to_mel(i, False))
        label.append(1)

        for i in range(5):
            data.append(path_to_mel(i, True))
            label.append(1)

    else:
        data.append(path_to_mel(i, False))
        label.append(0)
# Out:
#   0%|          | 0/3805 [00:00<?, ?it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_17224\246142194.py:12: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   0%|          | 1/3805 [00:01<1:18:56,  1.25s/it]C:\Users\aaa\AppData\Local\Temp\ipykernel_17224\246142194.py:12: FutureWarning: Pass y=[ 3.27749006e-09 -9.98302419e-09  4.54811797e-08 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   0%|          | 5/3805 [00:01<15:51,  4.00it/s]

# %%
BATCH_SIZE = 16
SHUFFLE_BUFFER_SIZE = 100
AUTOTUNE = tf.data.AUTOTUNE

train_ds = tf.data.Dataset.from_tensor_slices((data, label))
train_ds = train_ds.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)

# %%
def residual_block(x, filters_in, filters_out):
    shortcut = x
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Conv2D(filters_in, kernel_size=(1, 1), strides=(1, 1), padding="same",kernel_initializer='he_normal')(x)

    x = BatchNormalization()(x)
    x = ReLU()(x)    
    x = Conv2D(filters_in, kernel_size=(3, 3), strides=(1, 1), padding="same",kernel_initializer='he_normal')(x)

    x = BatchNormalization()(x)
    x = ReLU()(x)  
    x = Conv2D(filters_out, kernel_size=(1, 1), strides=(1, 1), padding="same",kernel_initializer='he_normal')(x)

    shortcut_channel = x.shape.as_list()[0]
    
    if shortcut_channel != filters_out:
        shortcut = Conv2D(filters_out, kernel_size=(1, 1), strides=(1, 1), padding="same",kernel_initializer='he_normal')(shortcut)
        
    x = Add()([x, shortcut])
    return ReLU()(x)

def build_model():

  inputs = tf.keras.layers.Input(shape=(40, 665, 1))

  outputs = Conv2D(16,(3,3),activation=None,padding='same',kernel_initializer='he_normal')(inputs)
  outputs = BatchNormalization()(outputs)
  outputs = ReLU()(outputs)
  outputs = MaxPool2D((2,2))(outputs)

  outputs = residual_block(outputs, 16, 32)
  outputs = MaxPool2D((2,2))(outputs)
  outputs = residual_block(outputs, 32, 32)
  # outputs = residual_block(outputs, 32, 32)
  outputs = residual_block(outputs, 32, 64)
  outputs = MaxPool2D((2,2))(outputs)
  outputs = residual_block(outputs, 64, 64)
  # outputs = residual_block(outputs, 64, 64)
  # outputs = MaxPool2D((2,2))(outputs)

  outputs = GlobalAveragePooling2D()(outputs)
  # outputs = Flatten()(outputs)

  outputs = Dense(32,activation=None,kernel_initializer='he_normal')(outputs)
  outputs = BatchNormalization()(outputs)
  outputs = ReLU()(outputs)
  outputs = Dropout(0.5)(outputs)

  outputs = Dense(2,activation='softmax')(outputs)
  model = Model(inputs=inputs, outputs=outputs)
  model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
  
  return model

model = build_model()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 40, 665, 1)  0           []
#                                 ]
#
#  conv2d_17 (Conv2D)             (None, 40, 665, 16)  160         ['input_2[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 40, 665, 16)  64         ['conv2d_17[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 40, 665, 16)  0           ['batch_normalization_14[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 20, 332, 16)  0          ['re_lu_18[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 20, 332, 16)  64         ['max_pooling2d_3[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 20, 332, 16)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 20, 332, 16)  272         ['re_lu_19[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 20, 332, 16)  64         ['conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 20, 332, 16)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 20, 332, 16)  2320        ['re_lu_20[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 20, 332, 16)  64         ['conv2d_19[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 20, 332, 16)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 20, 332, 32)  544         ['re_lu_21[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 20, 332, 32)  544         ['max_pooling2d_3[0][0]']
#
#  add_4 (Add)                    (None, 20, 332, 32)  0           ['conv2d_20[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  re_lu_22 (ReLU)                (None, 20, 332, 32)  0           ['add_4[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 10, 166, 32)  0          ['re_lu_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 10, 166, 32)  128        ['max_pooling2d_4[0][0]']
#  ormalization)
#
#  re_lu_23 (ReLU)                (None, 10, 166, 32)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 10, 166, 32)  1056        ['re_lu_23[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 10, 166, 32)  128        ['conv2d_22[0][0]']
#  ormalization)
#
#  re_lu_24 (ReLU)                (None, 10, 166, 32)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 10, 166, 32)  9248        ['re_lu_24[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 10, 166, 32)  128        ['conv2d_23[0][0]']
#  ormalization)
#
#  re_lu_25 (ReLU)                (None, 10, 166, 32)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 10, 166, 32)  1056        ['re_lu_25[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 10, 166, 32)  1056        ['max_pooling2d_4[0][0]']
#
#  add_5 (Add)                    (None, 10, 166, 32)  0           ['conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  re_lu_26 (ReLU)                (None, 10, 166, 32)  0           ['add_5[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 10, 166, 32)  128        ['re_lu_26[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 10, 166, 32)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 10, 166, 32)  1056        ['re_lu_27[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 10, 166, 32)  128        ['conv2d_26[0][0]']
#  ormalization)
#
#  re_lu_28 (ReLU)                (None, 10, 166, 32)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 10, 166, 32)  9248        ['re_lu_28[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 10, 166, 32)  128        ['conv2d_27[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 10, 166, 32)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 10, 166, 64)  2112        ['re_lu_29[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 10, 166, 64)  2112        ['re_lu_26[0][0]']
#
#  add_6 (Add)                    (None, 10, 166, 64)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  re_lu_30 (ReLU)                (None, 10, 166, 64)  0           ['add_6[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 5, 83, 64)   0           ['re_lu_30[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 5, 83, 64)   256         ['max_pooling2d_5[0][0]']
#  ormalization)
#
#  re_lu_31 (ReLU)                (None, 5, 83, 64)    0           ['batch_normalization_24[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 5, 83, 64)    4160        ['re_lu_31[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 5, 83, 64)   256         ['conv2d_30[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 5, 83, 64)    0           ['batch_normalization_25[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 5, 83, 64)    36928       ['re_lu_32[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 5, 83, 64)   256         ['conv2d_31[0][0]']
#  ormalization)
#
#  re_lu_33 (ReLU)                (None, 5, 83, 64)    0           ['batch_normalization_26[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 5, 83, 64)    4160        ['re_lu_33[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 5, 83, 64)    4160        ['max_pooling2d_5[0][0]']
#
#  add_7 (Add)                    (None, 5, 83, 64)    0           ['conv2d_32[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  re_lu_34 (ReLU)                (None, 5, 83, 64)    0           ['add_7[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 64)          0           ['re_lu_34[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 32)           2080        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  batch_normalization_27 (BatchN  (None, 32)          128         ['dense_2[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 32)           0           ['batch_normalization_27[0][0]']
#
#  dropout_1 (Dropout)            (None, 32)           0           ['re_lu_35[0][0]']
#
#  dense_3 (Dense)                (None, 2)            66          ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 84,258
# Trainable params: 83,298
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
history = model.fit(train_ds, epochs=2)
# Out:
# Epoch 1/2
# c:\Users\aaa\.conda\envs\tf\lib\site-packages\tensorflow\python\util\dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 238/238 [==============================] - 45s 146ms/step - loss: 0.1642 - accuracy: 0.9719
# Epoch 2/2
# 238/238 [==============================] - 32s 134ms/step - loss: 0.0300 - accuracy: 0.9995

# %%
inf_path = glob('data\\test\\*.*')

inf_data = []
for i in tqdm(inf_path):
    inf_data.append(path_to_mel(i, False))
# Out:
#   0%|          | 0/5732 [00:00<?, ?it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   1%|          | 48/5732 [00:06<12:56,  7.32it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[ 1.39155345e-11 -6.97332803e-10 -3.40985773e-09 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   1%|          | 52/5732 [00:06<12:21,  7.66it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-7.84149620e-07  8.31223701e-07 -8.06613343e-07 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   1%|▏         | 77/5732 [00:09<13:13,  7.13it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-2.96573584e-13  1.93848233e-13  1.28768049e-13 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   2%|▏         | 115/5732 [00:15<13:08,  7.12it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[ 2.49415644e-11 -4.56359880e-11  1.66571923e-10 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   2%|▏         | 122/5732 [00:16<13:52,  6.74it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-1.14069515e-07  9.35740943e-08 -5.64389353e-08 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   2%|▏         | 139/5732 [00:18<12:38,  7.37it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[ 4.51609372e-09 -9.95934570e-08 -1.93535016e-07 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   2%|▏         | 143/5732 [00:19<12:16,  7.58it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-5.69911002e-12  1.16181934e-11 -1.97253932e-11 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   3%|▎         | 144/5732 [00:19<11:46,  7.90it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[ 5.61636293e-10 -8.06062883e-10  9.47923740e-10 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   3%|▎         | 173/5732 [00:23<12:50,  7.21it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-8.20881123e-12  1.73667539e-11 -3.11607060e-11 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   3%|▎         | 197/5732 [00:26<11:06,  8.31it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[ 2.18876653e-11  1.88472519e-11 -8.12569179e-10 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   4%|▍         | 231/5732 [00:31<11:39,  7.86it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-7.84092606e-07  8.31173281e-07 -8.06587025e-07 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   4%|▍         | 251/5732 [00:34<13:23,  6.82it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-7.84131601e-07  8.31209434e-07 -8.06610615e-07 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   4%|▍         | 256/5732 [00:34<12:24,  7.36it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-9.18916956e-11  1.00576228e-10  1.02856945e-09 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   5%|▍         | 274/5732 [00:37<10:47,  8.43it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-1.84160465e-09 -1.12953513e-09  4.86035745e-09 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   5%|▌         | 291/5732 [00:39<12:13,  7.41it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-8.40151559e-11  7.89339794e-09  4.57153462e-08 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   5%|▌         | 292/5732 [00:39<12:07,  7.48it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[ 6.38098718e-15  5.03378914e-13 -1.59018697e-12 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#   5%|▌         | 297/5732 [00:40<11:31,  7.86it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[ 3.46814981e-12 -1.53091463e-11  2.73460948e-10 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-7.84110284e-07  8.31191073e-07 -8.06601633e-07 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  94%|█████████▎| 5369/5732 [12:19<00:56,  6.44it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-3.72161330e-11 -7.94216914e-11 -1.52344481e-09 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  94%|█████████▍| 5378/5732 [12:21<00:49,  7.19it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-4.41769295e-11  1.77453871e-10 -3.36136896e-10 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  94%|█████████▍| 5381/5732 [12:21<00:48,  7.21it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-1.35256641e-11  1.53737434e-09  7.27206206e-09 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  94%|█████████▍| 5382/5732 [12:21<00:54,  6.37it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-5.55701873e-11  4.40326525e-10  1.89314742e-09 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  94%|█████████▍| 5390/5732 [12:23<00:51,  6.61it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-1.16884280e-11  1.52228629e-11 -1.49330340e-11 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  94%|█████████▍| 5393/5732 [12:23<00:49,  6.88it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-1.64314189e-12  2.06614378e-11  2.19148699e-10 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  95%|█████████▍| 5429/5732 [12:28<00:43,  6.95it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[ 1.95782865e-12 -4.08052455e-12  7.40796834e-12 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  96%|█████████▌| 5481/5732 [12:35<00:33,  7.40it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-1.50389440e-07  4.43000303e-08 -3.90681606e-07 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  96%|█████████▌| 5482/5732 [12:35<00:34,  7.18it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-7.84107783e-07  8.31182888e-07 -8.06586172e-07 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  96%|█████████▋| 5527/5732 [12:41<00:28,  7.14it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-1.23966679e-12  5.13512887e-12 -1.64212983e-11 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  97%|█████████▋| 5541/5732 [12:43<00:25,  7.50it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-7.84126883e-07  8.31203636e-07 -8.06605726e-07 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  97%|█████████▋| 5547/5732 [12:44<00:24,  7.52it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-8.25635453e-08  4.75913069e-08 -1.13576874e-07 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  97%|█████████▋| 5582/5732 [12:49<00:18,  7.98it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-3.58521997e-11  4.55231339e-11 -1.77135029e-09 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  98%|█████████▊| 5589/5732 [12:50<00:18,  7.87it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-7.84125632e-07  8.31195734e-07 -8.06587025e-07 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
#  98%|█████████▊| 5643/5732 [12:57<00:12,  7.04it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-2.96540188e-11  5.65691140e-11 -1.89402563e-10 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
# 100%|█████████▉| 5713/5732 [13:07<00:03,  6.29it/s]C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\246142194.py:12: FutureWarning: Pass y=[-1.41786000e-10  1.75682968e-10 -1.89898472e-10 ...  0.00000000e+00
#   0.00000000e+00  0.00000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel = librosa.feature.melspectrogram(audio, sr=sr, n_mels=40)
# 100%|██████████| 5732/5732 [13:10<00:00,  7.25it/s]

# %%
inf_data_reshaped = []

for i in tqdm(inf_data):
    inf_data_reshaped.append(i.reshape(-1, 40, 665, 1))
# Out:
# 100%|██████████| 5732/5732 [00:00<00:00, 1146264.45it/s]

# %%
# Model 추론
inf_result = []

for i in tqdm(inf_data_reshaped):
    preds = model.predict(i)
    score = tf.nn.softmax(preds[0])
    class_names = [0,1]

    inf_result.append(class_names[np.argmax(score)])

# %%
np.max(inf_result)
# Out:
# 0

# %%
submission = pd.read_csv('data/sample_submission.csv')
submission = submission.drop('covid19', 1)
submission['covid19'] = inf_result
submission.to_csv('resnet_block_limited_data_mel.csv', index=False)
# Out:
# C:\Users\aaa\AppData\Local\Temp\ipykernel_6208\4158339642.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   submission = submission.drop('covid19', 1)
